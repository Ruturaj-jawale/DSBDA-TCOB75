# %%
import pandas as pd
import numpy as np

df = pd.read_csv(r'C:\Home\TCOB06\StudentPerformance.csv')
print(df)
# Out:
#     Gender  Math_Score  Reading_Score  Writing_Score  Placement_Score  \
# 0   female        69.0           85.0           62.0             99.0
# 1    male         62.0           91.0           60.0             65.0
# 2    male         69.0           79.0           99.0             87.0
# 3   female        55.0           84.0           94.0             85.0
# 4   female        88.0           84.0           64.0             76.0
# 5    male         77.0           79.0           99.0             88.0
# 6   female        66.0           56.0           68.0             76.0
# 7   female        67.0           91.0           63.0             84.0
# 8    male          NaN           85.0            NaN             77.0
# 9    male         75.0           84.0           71.0             81.0
# 10  female        61.0           79.0           76.0              NaN
# 11  female        71.0           84.0           76.0             89.0
# ...

# %%
series = pd.isnull(df["Math_Score"])
df[series]
# Out:
#   Gender  Math_Score  Reading_Score  Writing_Score  Placement_Score  \
# 8  male          NaN           85.0            NaN             77.0
#
#    Club_Join_Date  placement offer count
# 8            2018                       2

# %%
df.notnull()
# Out:
#     Gender  Math_Score  Reading_Score  Writing_Score  Placement_Score  \
# 0     True        True           True           True             True
# 1     True        True           True           True             True
# 2     True        True           True           True             True
# 3     True        True           True           True             True
# 4     True        True           True           True             True
# 5     True        True           True           True             True
# 6     True        True           True           True             True
# 7     True        True           True           True             True
# 8     True       False           True          False             True
# 9     True        True           True           True             True
# 10    True        True           True           True            False
# 11    True        True           True           True             True
# ...

# %%
series = pd.notnull(df["Math_Score"])
df[series]
# Out:
#     Gender  Math_Score  Reading_Score  Writing_Score  Placement_Score  \
# 0   female        69.0           85.0           62.0             99.0
# 1    male         62.0           91.0           60.0             65.0
# 2    male         69.0           79.0           99.0             87.0
# 3   female        55.0           84.0           94.0             85.0
# 4   female        88.0           84.0           64.0             76.0
# 5    male         77.0           79.0           99.0             88.0
# 6   female        66.0           56.0           68.0             76.0
# 7   female        67.0           91.0           63.0             84.0
# 9    male         75.0           84.0           71.0             81.0
# 10  female        61.0           79.0           76.0              NaN
# 11  female        71.0           84.0           76.0             89.0
# 12   male         78.0           80.0           75.0             89.0
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['Gender'] = le.fit_transform(df['Gender'])
df1 =df
print(df1)
# Out:
#     Gender  Math_Score  Reading_Score  Writing_Score  Placement_Score  \
# 0        0        69.0           85.0           62.0             99.0
# 1        1        62.0           91.0           60.0             65.0
# 2        1        69.0           79.0           99.0             87.0
# 3        0        55.0           84.0           94.0             85.0
# 4        0        88.0           84.0           64.0             76.0
# 5        1        77.0           79.0           99.0             88.0
# 6        0        66.0           56.0           68.0             76.0
# 7        0        67.0           91.0           63.0             84.0
# 8        1         NaN           85.0            NaN             77.0
# 9        1        75.0           84.0           71.0             81.0
# 10       0        61.0           79.0           76.0              NaN
# 11       0        71.0           84.0           76.0             89.0
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['Gender']=le.fit_transform(df['Gender'])
df1 = df

# %%
df = pd.read_csv(r'C:\Home\TCOB06\StudentPerformance.csv',na_values=["Na","na"])
print(df)
# Out:
#     Gender  Math_Score  Reading_Score  Writing_Score  Placement_Score  \
# 0
gender  Math_Score  Reading_Score  Writing_Score  Placement_Score  \
# 0   female   69.000000           85.0           62.0             99.0
# 1    male    62.000000           91.0           60.0             65.0
# 2    male    69.000000           79.0           99.0             87.0
# 3   female   55.000000           84.0           94.0             85.0
# 4   female   88.000000           84.0           64.0             76.0
# 5    male    77.000000           79.0           99.0             88.0
# 6   female   66.000000           56.0           68.0             76.0
# 7   female   67.000000           91.0           63.0             84.0
# 8    male    71.464286           85.0            NaN             77.0
# 9    male    75.000000           84.0           71.0             81.0
# 10  female   61.000000           79.0           76.0              NaN
# 11  female   71.000000           84.0           76.0             89.0
# ...

# %%
ndf.dropna(axis = 1)
# Out:
#     Gender  Math_Score  Club_Join_Date  placement offer count
# 0   female   69.000000            2018                       3
# 1    male    62.000000            2019                       1
# 2    male    69.000000            2021                       3
# 3   female   55.000000            2021                       3
# 4   female   88.000000            2020                       2
# 5    male    77.000000            2021                       3
# 6   female   66.000000            2020                       2
# 7   female   67.000000            2020                       2
# 8    male    71.464286            2018                       2
# 9    male    75.000000            2020                       2
# 10  female   61.000000            2021                       1
# 11  female   71.000000            2021                       3
# 12   male    78.000000            2020                       3
# 13  female   73.000000            2020                       1
# ...

# %%
ndf.dropna(axis = 0)
# Out:
#     Gender  Math_Score  Reading_Score  Writing_Score  Placement_Score  \
# 0   female        69.0           85.0           62.0             99.0
# 1    male         62.0           91.0           60.0             65.0
# 2    male         69.0           79.0           99.0             87.0
# 3   female        55.0           84.0           94.0             85.0
# 4   female        88.0           84.0           64.0             76.0
# 5    male         77.0           79.0           99.0             88.0
# 6   female        66.0           56.0           68.0             76.0
# 7   female        67.0           91.0           63.0             84.0
# 9    male         75.0           84.0           71.0             81.0
# 11  female        71.0           84.0           76.0             89.0
# 12   male         78.0           80.0           75.0             89.0
# 13  female        73.0           75.0           60.0             81.0
# ...

# %%
col = ['Math_Score', 'Reading_Score' , 'Writing_Score','Placement_Score']
df.boxplot(col)
# Out:
# <Axes: >

# %%
print(np.where(df['Math_Score']>90))
print(np.where(df['Reading_Score']<80))
print(np.where(df['Writing_Score']<90))
# Out:
# (array([], dtype=int64),)
# (array([ 2,  5,  6, 10, 13, 15, 16, 18, 21, 25, 27]),)
# (array([ 0,  1,  4,  6,  7,  9, 10, 11, 12, 13, 14, 15, 17, 18, 19, 20, 21,
#        22, 24, 25, 26, 27, 28]),)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv(r'C:\Home\TCOB06\StudentPerformance.csv')

df.columns = df.columns.str.strip()

fig, ax = plt.subplots(figsize = (18,10))
ax.scatter(df['Placement_Score'], df['placement offer count'])
plt.show()

# %%
df = pd.read_csv(r'C:\Home\TCOB06\StudentPerformance.csv')

# Strip leading/trailing spaces from column names
df.columns = df.columns.str.strip()

print(np.where((df['Placement_Score']<50) & (df['placement offer count']>1)))
print(np.where((df['Placement_Score']>85) & (df['placement offer count']<3)))
# Out:
# (array([], dtype=int64),)
# (array([10]),)

# %%
df['Math_Score'].plot(kind='hist', title='Math Score Distribution', bins=20)
plt.show()

# %%
df['Reading_Score'].plot(kind='hist', title='Reading Score Distribution', bins=20)
plt.show()

# %%
df['Writing_Score'].plot(kind='hist', title='Writing Score Distribution', bins=20)
plt.show()
